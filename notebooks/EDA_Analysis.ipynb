# %% [markdown]
# # Mutual Fund Analytics - EDA Analysis
#
# Author: Anushka Das
#
# Project: Capstone Project I - Mutual Fund Analytics
#
# Day 3 - Exploratory Data Analysis

# %% [markdown]
# Insight 1: Daily NAV values showed a generally upward trend between 2022 and 2025, indicating long-term growth across most mutual fund schemes. (Chart: nav_trends.png)

# %% [markdown]
# Insight 2: SBI Mutual Fund consistently maintained the highest Assets Under Management (AUM) among all fund houses. (Chart: aum_growth.png)

# %% [markdown]
# Insight 3: SIP inflows increased steadily from 2022 to 2025, reflecting rising retail participation in mutual funds. (Chart: sip_trend.png)

# %% [markdown]
# Insight 4: Large Cap and Flexi Cap categories received some of the highest net inflows across the observed period. (Chart: category_heatmap.png)

# %% [markdown]
# Insight 5: The 26–35 age group represented a significant share of investors in the dataset. (Chart: age_distribution.png)

# %% [markdown]
# Insight 6: Gender participation appeared relatively balanced, though one segment showed a slight majority. (Chart: gender_distribution.png)

# %% [markdown]
# Insight 7: Major metropolitan states generated the highest transaction volumes and investment activity. (Chart: state_transactions.png)

# %% [markdown]
# Insight 8: T30 cities accounted for a larger share of mutual fund participation than B30 cities. (Chart: t30_b30.png)

# %% [markdown]
# Insight 9: Industry folio counts increased substantially between 2022 and 2025, demonstrating growth in investor adoption. (Chart: folio_growth.png)

# %% [markdown]
# Insight 10: Several funds displayed strong positive NAV return correlations, indicating similar market exposure patterns. (Chart: nav_correlation.png)

# %%
print("EDA Analysis Completed Successfully")
# Out:
# EDA Analysis Completed Successfully
