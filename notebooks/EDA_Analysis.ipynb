# %% [markdown]
# # Mutual Fund Analytics - Exploratory Data Analysis (EDA)
#
# Capstone Project I
# Author: Anushka Das
# Day 3 - EDA Analysis

# %% [markdown]
# ## Dataset Overview
#
# This analysis uses 10 mutual fund datasets including NAV history, SIP inflows, investor transactions, AUM data, and portfolio holdings.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

print("EDA Notebook Loaded")
# Out:
# EDA Notebook Loaded

# %%
nav = pd.read_csv("../data/processed/02_nav_history_clean.csv")
sip = pd.read_csv("../data/processed/04_monthly_sip_inflows_clean.csv")
aum = pd.read_csv("../data/processed/03_aum_by_fund_house_clean.csv")
transactions = pd.read_csv("../data/processed/08_investor_transactions_clean.csv")
holdings = pd.read_csv("../data/processed/09_portfolio_holdings_clean.csv")

print("Datasets loaded:", len(nav), len(sip))
# Out:
# Datasets loaded: 46000 48

# %% [markdown]
# ## Insight 1
# NAV trends show steady long-term growth across most schemes, indicating strong fund performance over 2022–2025.

# %% [markdown]
# ## Insight 2
# SBI Mutual Fund dominates AUM across fund houses, indicating market leadership in assets under management.

# %% [markdown]
# ## Insight 3
# SIP inflows show a consistent upward trend, highlighting increasing retail investor participation.

# %% [markdown]
# ## Insight 4
# Large Cap and Flexi Cap categories receive the highest net inflows, indicating investor preference for stability and hybrid exposure.

# %% [markdown]
# ## Insight 5
# Investor participation is highest in the 26–35 age group, showing strong young investor adoption.

# %% [markdown]
# ## Insight 6
# T30 cities dominate mutual fund investments compared to B30 cities, indicating urban concentration of financial literacy.

# %% [markdown]
# ## Insight 7
# Transaction volumes are significantly higher in metro states like Maharashtra and Karnataka.

# %% [markdown]
# ## Insight 8
# Expense ratio remains within a stable range across most funds, with few outliers exceeding 2%.

# %% [markdown]
# ## Insight 9
# NAV correlation heatmap shows clusters of funds moving together, indicating similar market exposure.

# %% [markdown]
# ## Insight 10
# Sector allocation is heavily weighted toward Banking and IT sectors across equity funds.

# %%
print("EDA Analysis Completed Successfully")
# Out:
# EDA Analysis Completed Successfully
